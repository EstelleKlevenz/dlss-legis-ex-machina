# %% [markdown]
# # Merging all speeches with Speaker names and parties by Speaker_ID
#
# Using the csv files for speeches and the one for all speaker names to merge all to one Dataframe.

# %%
# Setup -load packages
import pandas as pd

# load data 
speeches = pd.read_csv("../data/speeches.csv")
speakers = pd.read_csv("../data/speaker_names.csv")

# %%
# Merge using inner join
merged_df = pd.merge(
    speeches,
    speakers,
    left_on='speaker_id',
    right_on='speakerId',
    how='inner'  # only keep speeches where speaker id was identifyable, -> none excluded! 
)

# drop double index column
merged_df = merged_df.drop(columns=['index'])

# %%
# testing if it worked -> I think Yes :)
merged_df[merged_df['speaker_id'] == 11001235]
merged_df[merged_df['lastName'] == "Kubicki"]

len(merged_df[merged_df['speaker_id'] == 11001235]) == len(merged_df[merged_df['lastName'] == "Kubicki"])
# Out:
#                                   speech_id  speaker_id  \
# 0      f7f58b13-85f3-424a-6864-08da102a68d8    11001235
# 2171   a6ce0cec-fe4d-4e48-f374-08da0daf380d    11001235
# 4278   fd03b172-2c14-40f2-5103-08da0f22a008    11001235
# 16072  a82725de-be48-469d-4bad-08da0e9b3c58    11001235
# 18768  d8017e34-d6e6-472f-0567-08da0f05b642    11001235
# 19084  c1cb0e25-817e-430e-708b-08da0f22a008    11001235
# 20326  dd1e7a36-80e0-4717-93ba-08da0e372f11    11001235
# 20831  f9c9758e-2e89-4f4a-6c65-08da102a68d8    11001235
# 23675  cd0818fd-e9fd-4d47-4fb3-08da0f22a008    11001235
# 23989  80576d3f-029a-4210-26a9-08da0d9e2391    11001235
# 25155  c5f0542b-42ae-410f-4771-08da84f73450    11001235
# 30476  bb8d1ca4-b952-4b2f-a794-70f0500773a9    11001235
#
#                                              speech_text  legislative_period  \
# 0      Herr Präsident, ich nehme die Wahl an.\nDann b...                  19
# 2171   Frau Präsidentin! Liebe Kolleginnen und Kolleg...                  19
# 4278   Frau Präsidentin! Liebe Kolleginnen und Kolleg...                  19
# 16072  Frau Präsidentin! Liebe Kolleginnen und Kolleg...                  19
# 18768  Frau Präsidentin! Liebe Kolleginnen und Kolleg...                  19
# 19084  Herr Kollege Rainer, bei Ihrer in Teilen bemer...                  19
# 20326  Frau Präsidentin! Liebe Kolleginnen und Kolleg...                  19
# 20831  Herr Kollege Binding, ich habe Ihrer Rede mit ...                  19
# 23675  Frau Präsidentin, ich nehme die Wahl sehr gern...                  20
# 23989  Frau Präsidentin! Liebe Kolleginnen und Kolleg...                  20
# 25155  Frau Präsidentin! Liebe Kolleginnen und Kolleg...                  20
# 30476  Verehrte Frau Präsidentin! Liebe Kolleginnen u...                  20
#
#        protocol_nr  agenda_item_number  speakerId firstName lastName party  \
# 0                1                   6   11001235  Wolfgang  Kubicki   FDP
# 2171           120                   3   11001235  Wolfgang  Kubicki   FDP
# 4278            14                  13   11001235  Wolfgang  Kubicki   FDP
# 16072          239                   2   11001235  Wolfgang  Kubicki   FDP
# 18768           52                  10   11001235  Wolfgang  Kubicki   FDP
# 19084           55                  18   11001235  Wolfgang  Kubicki   FDP
# 20326           67                   1   11001235  Wolfgang  Kubicki   FDP
# 20831           71                  13   11001235  Wolfgang  Kubicki   FDP
# 23675            1                   6   11001235  Wolfgang  Kubicki   FDP
# 23989           13                   3   11001235  Wolfgang  Kubicki   FDP
# 25155           28                   1   11001235  Wolfgang  Kubicki   FDP
# 30476           74                   8   11001235  Wolfgang  Kubicki   FDP
#
#       fraction
# 0          FDP
# 2171       FDP
# 4278       FDP
# 16072      FDP
# 18768      FDP
# 19084      FDP
# 20326      FDP
# 20831      FDP
# 23675      FDP
# 23989      FDP
# 25155      FDP
# 30476      FDP

# %%
# save data 
merged_df.to_csv("../data/complete_data.csv",index=False)
